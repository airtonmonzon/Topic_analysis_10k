# %% [markdown]
# # TFM: Analisis de Topicos en 10-k - Empresas del SP500
#
# ## Parte 1: Descarga de 10-k de las compañias

# %%
import os
import re
import shutil
from pathlib import Path
from sec_edgar_downloader import Downloader
from typing import List, Dict
from datetime import datetime
import pandas as pd
from bs4 import BeautifulSoup
import sys

# AÑADIDO PARA UTF-8 EN CONSOLA WINDOWS
#sys.stdout.reconfigure(encoding='utf-8')

EMAIL = "tu_email@ejemplo.com"  # Correo para SEC EDGAR
FORM_TYPE = "10-K"  # Tipo de formulario
START_YEAR = 2016  # Año inicial
CURRENT_YEAR = 2025  # Año final

BASE_DIR = "D:/TFM/Analisis_10k"  # o "D:\\10K_Data" si prefieres doble barra

INPUT_ROOT = f"{BASE_DIR}/Input"
TEMP_DIR = f"{BASE_DIR}/temp_10k_filings"
COMPANIES_EXCEL = f"{BASE_DIR}/companies_cik.xlsx"

# Empresas faltantes
#COMPANIES_EXCEL = f"{BASE_DIR}/companies_cik_faltante.xlsx"

def load_companies_from_excel(excel_path: str) -> List[Dict]:
    """Carga la información de las empresas desde un archivo Excel."""
    try:
        # Leer el Excel, asegurando que 'cik' sea string
        df = pd.read_excel(excel_path, dtype={'cik': str})
        
        # Convertir el DataFrame a una lista de diccionarios
        companies = df.to_dict('records')
        
        # Verificar que las columnas requeridas estén presentes
        required_columns = ['company_name', 'cik', 'company_dir']
        if not all(col in df.columns for col in required_columns):
            missing = [col for col in required_columns if col not in df.columns]
            raise ValueError(f"Faltan columnas en el Excel: {missing}")
        
        return companies
    except Exception as e:
        print(f"Error al leer el archivo Excel {excel_path}: {e}")
        return []

def extract_filing_date(file_path: Path) -> str:
    """Extrae la fecha de presentación del archivo 10-K, soportando texto y HTML."""
    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            text = f.read()
        match = re.search(r'<FILING-DATE>(\d{8})', text)
        if match:
            return pd.to_datetime(match.group(1), format='%Y%m%d').strftime('%Y-%m-%d')
        match = re.search(r'<ACCEPTANCE-DATETIME>(\d{8})', text)
        if match:
            return pd.to_datetime(match.group(1), format='%Y%m%d').strftime('%Y-%m-%d')
        soup = BeautifulSoup(text, 'html.parser')
        for tag in soup.find_all(text=re.compile(r'(FILING-DATE|ACCEPTANCE-DATETIME)')):
            match = re.search(r'\d{8}', tag)
            if match:
                return pd.to_datetime(match.group(0), format='%Y%m%d').strftime('%Y-%m-%d')
        print(f"No se encontró fecha en {file_path}")
        return None
    except Exception as e:
        print(f"Error extrayendo fecha de {file_path}: {e}")
        return None

def move_to_date_folder(file_path: Path, company_dir: str, filing_date: str) -> Path:
    """Mueve el archivo a la carpeta Input/company/date y retorna la nueva ruta."""
    target_dir = Path(INPUT_ROOT) / company_dir / filing_date
    target_dir.mkdir(parents=True, exist_ok=True)
    target_path = target_dir / file_path.name
    file_path.rename(target_path)
    return target_path

def clean_temp_dir(temp_dir: Path):
    """Elimina todos los archivos y carpetas en el directorio temporal."""
    if temp_dir.exists():
        shutil.rmtree(temp_dir, ignore_errors=True)
        print(f"Eliminado directorio temporal: {temp_dir}")
    temp_dir.mkdir(parents=True, exist_ok=True)

def download_10k_filings(
    companies: List[Dict],
    email: str,
    form_type: str,
    start_year: int,
    current_year: int,
    input_root: str,
    temp_dir: str
) -> None:
    """Descarga formularios 10-K y los organiza en Input/company/date."""
    temp_dir_path = Path(temp_dir)
    
    # Limpiar el directorio temporal al inicio
    clean_temp_dir(temp_dir_path)
    
    try:
        for company in companies:
            company_name = company["company_name"]
            cik = company["cik"]
            company_dir = company["company_dir"]
            dl = Downloader(company_name, email, temp_dir)
            
            # Descargar archivos año por año
            for year in range(start_year, current_year + 1):
                try:
                    print(f"Descargando {form_type} para {company_name}, año {year}...")
                    dl.get(form_type, cik, after=f"{year}-01-01", before=f"{year}-12-31")
                    print(f"Descarga completada para {company_name}, año {year}.")
                except Exception as e:
                    print(f"Error descargando {form_type} para {company_name}, año {year}: {e}")
            
            # Procesar archivos descargados
            temp_company_dir = Path(temp_dir) / "sec-edgar-filings" / str(cik) / form_type
            if not temp_company_dir.exists():
                print(f"No se encontraron archivos para {company_name} en {temp_company_dir}")
                continue
            
            for file_path in temp_company_dir.rglob("*.*"):
                filing_date = extract_filing_date(file_path)
                if not filing_date:
                    print(f"Omitiendo {file_path}: No se encontró fecha de presentación")
                    continue
                
                # Mover archivo y eliminarlo del directorio temporal
                new_path = move_to_date_folder(file_path, company_dir, filing_date)
                print(f"Movido {file_path} -> {new_path}")
                try:
                    file_path.unlink(missing_ok=True)  # Eliminar archivo temporal
                except Exception as e:
                    print(f"Error eliminando {file_path}: {e}")
            
            # Limpiar directorio temporal de la compañía
            try:
                shutil.rmtree(temp_company_dir, ignore_errors=True)
                print(f"Eliminado directorio temporal: {temp_company_dir}")
            except Exception as e:
                print(f"Error eliminando {temp_company_dir}: {e}")
    
    finally:
        # Limpiar TEMP_DIR al finalizar (en caso de error)
        clean_temp_dir(temp_dir_path)

def main():
    """Función principal para descargar y organizar formularios 10-K."""
    # Cargar empresas desde el Excel
    companies = load_companies_from_excel(COMPANIES_EXCEL)
    if not companies:
        print("No se cargaron empresas. Terminando ejecución.")
        return
    download_10k_filings(companies, EMAIL, FORM_TYPE, START_YEAR, CURRENT_YEAR, INPUT_ROOT, TEMP_DIR)

if __name__ == "__main__":
    main()
# Out:
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings
# Descargando 10-K para Brown_Forman, año 2016...
# Descarga completada para Brown_Forman, año 2016.
# Descargando 10-K para Brown_Forman, año 2017...
# Descarga completada para Brown_Forman, año 2017.
# Descargando 10-K para Brown_Forman, año 2018...
# Descarga completada para Brown_Forman, año 2018.
# Descargando 10-K para Brown_Forman, año 2019...
# Descarga completada para Brown_Forman, año 2019.
# Descargando 10-K para Brown_Forman, año 2020...
# Descarga completada para Brown_Forman, año 2020.
# Descargando 10-K para Brown_Forman, año 2021...
# Descarga completada para Brown_Forman, año 2021.
# Descargando 10-K para Brown_Forman, año 2022...
# Descarga completada para Brown_Forman, año 2022.
# Descargando 10-K para Brown_Forman, año 2023...
# Descarga completada para Brown_Forman, año 2023.
# Descargando 10-K para Brown_Forman, año 2024...
# Descarga completada para Brown_Forman, año 2024.
# Descargando 10-K para Brown_Forman, año 2025...
# Descarga completada para Brown_Forman, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-16-000160\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2016-06-15\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-17-000119\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2017-06-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-18-000084\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2018-06-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-19-000099\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2019-06-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-20-000066\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2020-06-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-21-000091\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2021-06-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-22-000069\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2022-06-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-23-000074\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2023-06-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K\0000014693-24-000086\full-submission.txt -> D:\TFM\Analisis_10k\Input\Brown_Forman\2024-06-14\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014693\10-K
# Descargando 10-K para Bristol_Myers_Squibb, año 2016...
# Descarga completada para Bristol_Myers_Squibb, año 2016.
# Descargando 10-K para Bristol_Myers_Squibb, año 2017...
# Descarga completada para Bristol_Myers_Squibb, año 2017.
# Descargando 10-K para Bristol_Myers_Squibb, año 2018...
# Descarga completada para Bristol_Myers_Squibb, año 2018.
# Descargando 10-K para Bristol_Myers_Squibb, año 2019...
# Descarga completada para Bristol_Myers_Squibb, año 2019.
# Descargando 10-K para Bristol_Myers_Squibb, año 2020...
# Descarga completada para Bristol_Myers_Squibb, año 2020.
# Descargando 10-K para Bristol_Myers_Squibb, año 2021...
# Descarga completada para Bristol_Myers_Squibb, año 2021.
# Descargando 10-K para Bristol_Myers_Squibb, año 2022...
# Descarga completada para Bristol_Myers_Squibb, año 2022.
# Descargando 10-K para Bristol_Myers_Squibb, año 2023...
# Descarga completada para Bristol_Myers_Squibb, año 2023.
# Descargando 10-K para Bristol_Myers_Squibb, año 2024...
# Descarga completada para Bristol_Myers_Squibb, año 2024.
# Descargando 10-K para Bristol_Myers_Squibb, año 2025...
# Descarga completada para Bristol_Myers_Squibb, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-16-000288\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2016-02-12\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-17-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2017-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-18-000055\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2018-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-19-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2019-02-25\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-20-000082\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2020-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-21-000066\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2021-02-10\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-22-000051\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2022-02-09\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-23-000046\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2023-02-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-24-000044\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2024-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K\0000014272-25-000039\full-submission.txt -> D:\TFM\Analisis_10k\Input\Bristol_Myers_Squibb\2025-02-12\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000014272\10-K
# Descargando 10-K para Boeing, año 2016...
# Descarga completada para Boeing, año 2016.
# Descargando 10-K para Boeing, año 2017...
# Descarga completada para Boeing, año 2017.
# Descargando 10-K para Boeing, año 2018...
# Descarga completada para Boeing, año 2018.
# Descargando 10-K para Boeing, año 2019...
# Descarga completada para Boeing, año 2019.
# Descargando 10-K para Boeing, año 2020...
# Descarga completada para Boeing, año 2020.
# Descargando 10-K para Boeing, año 2021...
# Descarga completada para Boeing, año 2021.
# Descargando 10-K para Boeing, año 2022...
# Descarga completada para Boeing, año 2022.
# Descargando 10-K para Boeing, año 2023...
# Descarga completada para Boeing, año 2023.
# Descargando 10-K para Boeing, año 2024...
# Descarga completada para Boeing, año 2024.
# Descargando 10-K para Boeing, año 2025...
# Descarga completada para Boeing, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-16-000099\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2016-02-10\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-17-000006\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2017-02-08\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-18-000007\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2018-02-12\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-19-000010\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2019-02-08\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-20-000014\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2020-01-31\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-21-000011\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2021-02-01\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-22-000010\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2022-01-31\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-23-000007\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2023-01-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-24-000010\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2024-01-31\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K\0000012927-25-000015\full-submission.txt -> D:\TFM\Analisis_10k\Input\Boeing\2025-02-03\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000012927\10-K
# Descargando 10-K para W_R_Berkley_Corporation, año 2016...
# Descarga completada para W_R_Berkley_Corporation, año 2016.
# Descargando 10-K para W_R_Berkley_Corporation, año 2017...
# Descarga completada para W_R_Berkley_Corporation, año 2017.
# Descargando 10-K para W_R_Berkley_Corporation, año 2018...
# Descarga completada para W_R_Berkley_Corporation, año 2018.
# Descargando 10-K para W_R_Berkley_Corporation, año 2019...
# Descarga completada para W_R_Berkley_Corporation, año 2019.
# Descargando 10-K para W_R_Berkley_Corporation, año 2020...
# Descarga completada para W_R_Berkley_Corporation, año 2020.
# Descargando 10-K para W_R_Berkley_Corporation, año 2021...
# Descarga completada para W_R_Berkley_Corporation, año 2021.
# Descargando 10-K para W_R_Berkley_Corporation, año 2022...
# Descarga completada para W_R_Berkley_Corporation, año 2022.
# Descargando 10-K para W_R_Berkley_Corporation, año 2023...
# Descarga completada para W_R_Berkley_Corporation, año 2023.
# Descargando 10-K para W_R_Berkley_Corporation, año 2024...
# Descarga completada para W_R_Berkley_Corporation, año 2024.
# Descargando 10-K para W_R_Berkley_Corporation, año 2025...
# Descarga completada para W_R_Berkley_Corporation, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-16-000086\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2016-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-17-000009\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2017-02-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-18-000012\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2018-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-19-000016\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2019-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-20-000016\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2020-02-20\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-21-000013\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2021-02-18\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-22-000007\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2022-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-23-000004\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2023-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-24-000005\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2024-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K\0000011544-25-000005\full-submission.txt -> D:\TFM\Analisis_10k\Input\W_R_Berkley_Corporation\2025-02-24\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000011544\10-K
# Descargando 10-K para Becton_Dickinson, año 2016...
# Descarga completada para Becton_Dickinson, año 2016.
# Descargando 10-K para Becton_Dickinson, año 2017...
# Descarga completada para Becton_Dickinson, año 2017.
# Descargando 10-K para Becton_Dickinson, año 2018...
# Descarga completada para Becton_Dickinson, año 2018.
# Descargando 10-K para Becton_Dickinson, año 2019...
# Descarga completada para Becton_Dickinson, año 2019.
# Descargando 10-K para Becton_Dickinson, año 2020...
# Descarga completada para Becton_Dickinson, año 2020.
# Descargando 10-K para Becton_Dickinson, año 2021...
# Descarga completada para Becton_Dickinson, año 2021.
# Descargando 10-K para Becton_Dickinson, año 2022...
# Descarga completada para Becton_Dickinson, año 2022.
# Descargando 10-K para Becton_Dickinson, año 2023...
# Descarga completada para Becton_Dickinson, año 2023.
# Descargando 10-K para Becton_Dickinson, año 2024...
# Descarga completada para Becton_Dickinson, año 2024.
# Descargando 10-K para Becton_Dickinson, año 2025...
# Descarga completada para Becton_Dickinson, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-17-000021\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2017-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-18-000036\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2018-11-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-19-000044\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2019-11-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-20-000055\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2020-11-25\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-21-000091\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2021-11-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-23-000098\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2023-11-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0000010795-24-000084\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2024-11-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0001628280-16-021658\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2016-11-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K\0001628280-22-030686\full-submission.txt -> D:\TFM\Analisis_10k\Input\Becton_Dickinson\2022-11-22\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010795\10-K
# Descargando 10-K para Baxter_International, año 2016...
# Descarga completada para Baxter_International, año 2016.
# Descargando 10-K para Baxter_International, año 2017...
# Descarga completada para Baxter_International, año 2017.
# Descargando 10-K para Baxter_International, año 2018...
# Descarga completada para Baxter_International, año 2018.
# Descargando 10-K para Baxter_International, año 2019...
# Descarga completada para Baxter_International, año 2019.
# Descargando 10-K para Baxter_International, año 2020...
# Descarga completada para Baxter_International, año 2020.
# Descargando 10-K para Baxter_International, año 2021...
# Descarga completada para Baxter_International, año 2021.
# Descargando 10-K para Baxter_International, año 2022...
# Descarga completada para Baxter_International, año 2022.
# Descargando 10-K para Baxter_International, año 2023...
# Descarga completada para Baxter_International, año 2023.
# Descargando 10-K para Baxter_International, año 2024...
# Descarga completada para Baxter_International, año 2024.
# Descargando 10-K para Baxter_International, año 2025...
# Descarga completada para Baxter_International, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001193125-16-479471\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2016-02-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001564590-17-002240\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2017-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001564590-18-002954\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2018-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001564590-19-003727\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2019-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-20-003693\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2020-03-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-21-001867\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2021-02-11\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-22-003432\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2022-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-23-002864\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2023-02-09\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-24-003932\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2024-02-08\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K\0001628280-25-007201\full-submission.txt -> D:\TFM\Analisis_10k\Input\Baxter_International\2025-02-21\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000010456\10-K
# Descargando 10-K para Ball_Corporation, año 2016...
# Descarga completada para Ball_Corporation, año 2016.
# Descargando 10-K para Ball_Corporation, año 2017...
# Descarga completada para Ball_Corporation, año 2017.
# Descargando 10-K para Ball_Corporation, año 2018...
# Descarga completada para Ball_Corporation, año 2018.
# Descargando 10-K para Ball_Corporation, año 2019...
# Descarga completada para Ball_Corporation, año 2019.
# Descargando 10-K para Ball_Corporation, año 2020...
# Descarga completada para Ball_Corporation, año 2020.
# Descargando 10-K para Ball_Corporation, año 2021...
# Descarga completada para Ball_Corporation, año 2021.
# Descargando 10-K para Ball_Corporation, año 2022...
# Descarga completada para Ball_Corporation, año 2022.
# Descargando 10-K para Ball_Corporation, año 2023...
# Descarga completada para Ball_Corporation, año 2023.
# Descargando 10-K para Ball_Corporation, año 2024...
# Descarga completada para Ball_Corporation, año 2024.
# Descargando 10-K para Ball_Corporation, año 2025...
# Descarga completada para Ball_Corporation, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0000009389-23-000011\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2023-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001104659-16-097390\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2016-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-17-001300\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2017-03-02\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-18-001345\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2018-02-28\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-19-000909\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2019-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-20-001005\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2020-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-21-001121\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2021-02-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-22-001251\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2022-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-24-001349\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2024-02-20\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K\0001558370-25-001190\full-submission.txt -> D:\TFM\Analisis_10k\Input\Ball_Corporation\2025-02-20\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000009389\10-K
# Descargando 10-K para Avery_Dennison, año 2016...
# Descarga completada para Avery_Dennison, año 2016.
# Descargando 10-K para Avery_Dennison, año 2017...
# Descarga completada para Avery_Dennison, año 2017.
# Descargando 10-K para Avery_Dennison, año 2018...
# Descarga completada para Avery_Dennison, año 2018.
# Descargando 10-K para Avery_Dennison, año 2019...
# Descarga completada para Avery_Dennison, año 2019.
# Descargando 10-K para Avery_Dennison, año 2020...
# Descarga completada para Avery_Dennison, año 2020.
# Descargando 10-K para Avery_Dennison, año 2021...
# Descarga completada para Avery_Dennison, año 2021.
# Descargando 10-K para Avery_Dennison, año 2022...
# Descarga completada para Avery_Dennison, año 2022.
# Descargando 10-K para Avery_Dennison, año 2023...
# Descarga completada para Avery_Dennison, año 2023.
# Descargando 10-K para Avery_Dennison, año 2024...
# Descarga completada para Avery_Dennison, año 2024.
# Descargando 10-K para Avery_Dennison, año 2025...
# Descarga completada para Avery_Dennison, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0000008818-23-000002\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2023-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0000008818-24-000003\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2024-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0000008818-25-000003\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2025-02-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001047469-16-010376\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2016-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001047469-17-000881\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2017-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001047469-18-000931\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2018-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001047469-19-000747\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2019-02-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001104659-20-025360\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2020-02-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001193125-21-055146\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2021-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K\0001193125-22-049910\full-submission.txt -> D:\TFM\Analisis_10k\Input\Avery_Dennison\2022-02-23\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008818\10-K
# Descargando 10-K para Automatic_Data_Processing, año 2016...
# Descarga completada para Automatic_Data_Processing, año 2016.
# Descargando 10-K para Automatic_Data_Processing, año 2017...
# Descarga completada para Automatic_Data_Processing, año 2017.
# Descargando 10-K para Automatic_Data_Processing, año 2018...
# Descarga completada para Automatic_Data_Processing, año 2018.
# Descargando 10-K para Automatic_Data_Processing, año 2019...
# Descarga completada para Automatic_Data_Processing, año 2019.
# Descargando 10-K para Automatic_Data_Processing, año 2020...
# Descarga completada para Automatic_Data_Processing, año 2020.
# Descargando 10-K para Automatic_Data_Processing, año 2021...
# Descarga completada para Automatic_Data_Processing, año 2021.
# Descargando 10-K para Automatic_Data_Processing, año 2022...
# Descarga completada para Automatic_Data_Processing, año 2022.
# Descargando 10-K para Automatic_Data_Processing, año 2023...
# Descarga completada para Automatic_Data_Processing, año 2023.
# Descargando 10-K para Automatic_Data_Processing, año 2024...
# Descarga completada para Automatic_Data_Processing, año 2024.
# Descargando 10-K para Automatic_Data_Processing, año 2025...
# Descarga completada para Automatic_Data_Processing, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008670\10-K\0000008670-16-000053\full-submission.txt -> D:\TFM\Analisis_10k\Input\Automatic_Data_Processing\2016-08-05\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000008670\10-K\0000008670-17-000010\full-submission.txt -> D:\TFM\Analisis_10k\Input\Automatic_Data_Processing\2017-08-04\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0
full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000007084\10-K\0000007084-23-000010\full-submission.txt -> D:\TFM\Analisis_10k\Input\Archer_Daniels_Midland\2023-02-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000007084\10-K\0000007084-24-000009\full-submission.txt -> D:\TFM\Analisis_10k\Input\Archer_Daniels_Midland\2024-03-12\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000007084\10-K\0000007084-25-000011\full-submission.txt -> D:\TFM\Analisis_10k\Input\Archer_Daniels_Midland\2025-02-20\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000007084\10-K
# Descargando 10-K para Applied_Materials, año 2016...
# Descarga completada para Applied_Materials, año 2016.
# Descargando 10-K para Applied_Materials, año 2017...
# Descarga completada para Applied_Materials, año 2017.
# Descargando 10-K para Applied_Materials, año 2018...
# Descarga completada para Applied_Materials, año 2018.
# Descargando 10-K para Applied_Materials, año 2019...
# Descarga completada para Applied_Materials, año 2019.
# Descargando 10-K para Applied_Materials, año 2020...
# Descarga completada para Applied_Materials, año 2020.
# Descargando 10-K para Applied_Materials, año 2021...
# Descarga completada para Applied_Materials, año 2021.
# Descargando 10-K para Applied_Materials, año 2022...
# Descarga completada para Applied_Materials, año 2022.
# Descargando 10-K para Applied_Materials, año 2023...
# Descarga completada para Applied_Materials, año 2023.
# Descargando 10-K para Applied_Materials, año 2024...
# Descarga completada para Applied_Materials, año 2024.
# Descargando 10-K para Applied_Materials, año 2025...
# Descarga completada para Applied_Materials, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-16-000068\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2016-12-15\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-17-000038\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2017-12-15\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-18-000041\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2018-12-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-19-000046\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2019-12-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-20-000048\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2020-12-11\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-21-000043\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2021-12-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-22-000043\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2022-12-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-23-000041\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2023-12-15\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K\0000006951-24-000044\full-submission.txt -> D:\TFM\Analisis_10k\Input\Applied_Materials\2024-12-13\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006951\10-K
# Descargando 10-K para Analog_Devices, año 2016...
# Descarga completada para Analog_Devices, año 2016.
# Descargando 10-K para Analog_Devices, año 2017...
# Descarga completada para Analog_Devices, año 2017.
# Descargando 10-K para Analog_Devices, año 2018...
# Descarga completada para Analog_Devices, año 2018.
# Descargando 10-K para Analog_Devices, año 2019...
# Descarga completada para Analog_Devices, año 2019.
# Descargando 10-K para Analog_Devices, año 2020...
# Descarga completada para Analog_Devices, año 2020.
# Descargando 10-K para Analog_Devices, año 2021...
# Descarga completada para Analog_Devices, año 2021.
# Descargando 10-K para Analog_Devices, año 2022...
# Descarga completada para Analog_Devices, año 2022.
# Descargando 10-K para Analog_Devices, año 2023...
# Descarga completada para Analog_Devices, año 2023.
# Descargando 10-K para Analog_Devices, año 2024...
# Descarga completada para Analog_Devices, año 2024.
# Descargando 10-K para Analog_Devices, año 2025...
# Descarga completada para Analog_Devices, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-16-000097\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2016-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-17-000144\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2017-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-18-000126\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2018-11-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-19-000144\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2019-11-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-20-000156\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2020-11-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-21-000294\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2021-12-03\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-22-000250\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2022-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-23-000203\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2023-11-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K\0000006281-24-000204\full-submission.txt -> D:\TFM\Analisis_10k\Input\Analog_Devices\2024-11-26\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000006281\10-K
# Descargando 10-K para American_International_Group, año 2016...
# Descarga completada para American_International_Group, año 2016.
# Descargando 10-K para American_International_Group, año 2017...
# Descarga completada para American_International_Group, año 2017.
# Descargando 10-K para American_International_Group, año 2018...
# Descarga completada para American_International_Group, año 2018.
# Descargando 10-K para American_International_Group, año 2019...
# Descarga completada para American_International_Group, año 2019.
# Descargando 10-K para American_International_Group, año 2020...
# Descarga completada para American_International_Group, año 2020.
# Descargando 10-K para American_International_Group, año 2021...
# Descarga completada para American_International_Group, año 2021.
# Descargando 10-K para American_International_Group, año 2022...
# Descarga completada para American_International_Group, año 2022.
# Descargando 10-K para American_International_Group, año 2023...
# Descarga completada para American_International_Group, año 2023.
# Descargando 10-K para American_International_Group, año 2024...
# Descarga completada para American_International_Group, año 2024.
# Descargando 10-K para American_International_Group, año 2025...
# Descarga completada para American_International_Group, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-16-000035\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2016-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-17-000017\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2017-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-18-000022\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2018-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-19-000023\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2019-02-15\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-23-000007\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2023-02-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-24-000023\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2024-02-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0000005272-25-000012\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2025-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0001104659-20-023889\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2020-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0001104659-21-025742\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2021-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K\0001104659-22-024701\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_International_Group\2022-02-17\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000005272\10-K
# Descargando 10-K para Aflac, año 2016...
# Descarga completada para Aflac, año 2016.
# Descargando 10-K para Aflac, año 2017...
# Descarga completada para Aflac, año 2017.
# Descargando 10-K para Aflac, año 2018...
# Descarga completada para Aflac, año 2018.
# Descargando 10-K para Aflac, año 2019...
# Descarga completada para Aflac, año 2019.
# Descargando 10-K para Aflac, año 2020...
# Descarga completada para Aflac, año 2020.
# Descargando 10-K para Aflac, año 2021...
# Descarga completada para Aflac, año 2021.
# Descargando 10-K para Aflac, año 2022...
# Descarga completada para Aflac, año 2022.
# Descargando 10-K para Aflac, año 2023...
# Descarga completada para Aflac, año 2023.
# Descargando 10-K para Aflac, año 2024...
# Descarga completada para Aflac, año 2024.
# Descargando 10-K para Aflac, año 2025...
# Descarga completada para Aflac, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-16-000259\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2016-02-25\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-17-000064\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2017-02-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-18-000054\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2018-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-19-000049\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2019-02-25\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-20-000044\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2020-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-21-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2021-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-22-000058\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2022-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-23-000055\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2023-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-24-000053\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2024-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K\0000004977-25-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Aflac\2025-02-26\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004977\10-K
# Descargando 10-K para American_Express, año 2016...
# Descarga completada para American_Express, año 2016.
# Descargando 10-K para American_Express, año 2017...
# Descarga completada para American_Express, año 2017.
# Descargando 10-K para American_Express, año 2018...
# Descarga completada para American_Express, año 2018.
# Descargando 10-K para American_Express, año 2019...
# Descarga completada para American_Express, año 2019.
# Descargando 10-K para American_Express, año 2020...
# Descarga completada para American_Express, año 2020.
# Descargando 10-K para American_Express, año 2021...
# Descarga completada para American_Express, año 2021.
# Descargando 10-K para American_Express, año 2022...
# Descarga completada para American_Express, año 2022.
# Descargando 10-K para American_Express, año 2023...
# Descarga completada para American_Express, año 2023.
# Descargando 10-K para American_Express, año 2024...
# Descarga completada para American_Express, año 2024.
# Descargando 10-K para American_Express, año 2025...
# Descarga completada para American_Express, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-18-000032\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2018-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-19-000018\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2019-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-20-000030\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2020-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-21-000013\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2021-02-12\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-22-000008\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2022-02-11\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-23-000006\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2023-02-10\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-24-000013\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2024-02-09\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0000004962-25-000016\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2025-02-07\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0001193125-16-469798\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2016-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K\0001193125-17-047588\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Express\2017-02-17\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004962\10-K
# Descargando 10-K para American_Electric_Power, año 2016...
# Descarga completada para American_Electric_Power, año 2016.
# Descargando 10-K para American_Electric_Power, año 2017...
# Descarga completada para American_Electric_Power, año 2017.
# Descargando 10-K para American_Electric_Power, año 2018...
# Descarga completada para American_Electric_Power, año 2018.
# Descargando 10-K para American_Electric_Power, año 2019...
# Descarga completada para American_Electric_Power, año 2019.
# Descargando 10-K para American_Electric_Power, año 2020...
# Descarga completada para American_Electric_Power, año 2020.
# Descargando 10-K para American_Electric_Power, año 2021...
# Descarga completada para American_Electric_Power, año 2021.
# Descargando 10-K para American_Electric_Power, año 2022...
# Descarga completada para American_Electric_Power, año 2022.
# Descargando 10-K para American_Electric_Power, año 2023...
# Descarga completada para American_Electric_Power, año 2023.
# Descargando 10-K para American_Electric_Power, año 2024...
# Descarga completada para American_Electric_Power, año 2024.
# Descargando 10-K para American_Electric_Power, año 2025...
# Descarga completada para American_Electric_Power, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004904\10-K\0000004904-16-000056\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Electric_Power\2016-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004904\10-K\0000004904-17-000019\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Electric_Power\2017-02-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004904\10-K\0000004904-18-000009\full-submission.txt -> D:\TFM\Analisis_10k\Input\American_Electric_Power\2018-02-22\full-submission.txt
# ...
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004447\10-K\0001628280-24-006845\full-submission.txt -> D:\TFM\Analisis_10k\Input\Hess_Corporation\2024-02-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004447\10-K\0001628280-25-008716\full-submission.txt -> D:\TFM\Analisis_10k\Input\Hess_Corporation\2025-02-27\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004447\10-K
# Descargando 10-K para Howmet_Aerospace, año 2016...
# Descarga completada para Howmet_Aerospace, año 2016.
# Descargando 10-K para Howmet_Aerospace, año 2017...
# Descarga completada para Howmet_Aerospace, año 2017.
# Descargando 10-K para Howmet_Aerospace, año 2018...
# Descarga completada para Howmet_Aerospace, año 2018.
# Descargando 10-K para Howmet_Aerospace, año 2019...
# Descarga completada para Howmet_Aerospace, año 2019.
# Descargando 10-K para Howmet_Aerospace, año 2020...
# Descarga completada para Howmet_Aerospace, año 2020.
# Descargando 10-K para Howmet_Aerospace, año 2021...
# Descarga completada para Howmet_Aerospace, año 2021.
# Descargando 10-K para Howmet_Aerospace, año 2022...
# Descarga completada para Howmet_Aerospace, año 2022.
# Descargando 10-K para Howmet_Aerospace, año 2023...
# Descarga completada para Howmet_Aerospace, año 2023.
# Descargando 10-K para Howmet_Aerospace, año 2024...
# Descarga completada para Howmet_Aerospace, año 2024.
# Descargando 10-K para Howmet_Aerospace, año 2025...
# Descarga completada para Howmet_Aerospace, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-18-000042\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2018-02-23\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-19-000031\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2019-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-20-000038\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2020-02-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-21-000049\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2021-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-22-000004\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2022-02-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-23-000004\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2023-02-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-24-000007\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2024-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0000004281-25-000011\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2025-02-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0001193125-16-470162\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2016-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K\0001193125-17-062657\full-submission.txt -> D:\TFM\Analisis_10k\Input\Howmet_Aerospace\2017-02-28\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004281\10-K
# Descargando 10-K para Skyworks_Solutions, año 2016...
# Descarga completada para Skyworks_Solutions, año 2016.
# Descargando 10-K para Skyworks_Solutions, año 2017...
# Descarga completada para Skyworks_Solutions, año 2017.
# Descargando 10-K para Skyworks_Solutions, año 2018...
# Descarga completada para Skyworks_Solutions, año 2018.
# Descargando 10-K para Skyworks_Solutions, año 2019...
# Descarga completada para Skyworks_Solutions, año 2019.
# Descargando 10-K para Skyworks_Solutions, año 2020...
# Descarga completada para Skyworks_Solutions, año 2020.
# Descargando 10-K para Skyworks_Solutions, año 2021...
# Descarga completada para Skyworks_Solutions, año 2021.
# Descargando 10-K para Skyworks_Solutions, año 2022...
# Descarga completada para Skyworks_Solutions, año 2022.
# Descargando 10-K para Skyworks_Solutions, año 2023...
# Descarga completada para Skyworks_Solutions, año 2023.
# Descargando 10-K para Skyworks_Solutions, año 2024...
# Descarga completada para Skyworks_Solutions, año 2024.
# Descargando 10-K para Skyworks_Solutions, año 2025...
# Descarga completada para Skyworks_Solutions, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-16-000068\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2016-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-17-000033\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2017-11-13\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-18-000046\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2018-11-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-19-000049\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2019-11-14\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-20-000058\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2020-11-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-21-000058\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2021-11-24\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-22-000038\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2022-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-23-000030\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2023-11-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K\0000004127-24-000131\full-submission.txt -> D:\TFM\Analisis_10k\Input\Skyworks_Solutions\2024-11-15\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000004127\10-K
# Descargando 10-K para Air_Products, año 2016...
# Descarga completada para Air_Products, año 2016.
# Descargando 10-K para Air_Products, año 2017...
# Descarga completada para Air_Products, año 2017.
# Descargando 10-K para Air_Products, año 2018...
# Descarga completada para Air_Products, año 2018.
# Descargando 10-K para Air_Products, año 2019...
# Descarga completada para Air_Products, año 2019.
# Descargando 10-K para Air_Products, año 2020...
# Descarga completada para Air_Products, año 2020.
# Descargando 10-K para Air_Products, año 2021...
# Descarga completada para Air_Products, año 2021.
# Descargando 10-K para Air_Products, año 2022...
# Descarga completada para Air_Products, año 2022.
# Descargando 10-K para Air_Products, año 2023...
# Descarga completada para Air_Products, año 2023.
# Descargando 10-K para Air_Products, año 2024...
# Descarga completada para Air_Products, año 2024.
# Descargando 10-K para Air_Products, año 2025...
# Descarga completada para Air_Products, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-17-000039\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2017-11-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-18-000044\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2018-11-20\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-19-000051\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2019-11-26\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-20-000049\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2020-11-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-21-000055\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2021-11-18\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-22-000054\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2022-11-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-23-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2023-11-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0000002969-24-000056\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2024-11-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K\0001193125-16-773346\full-submission.txt -> D:\TFM\Analisis_10k\Input\Air_Products\2016-11-21\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002969\10-K
# Descargando 10-K para Advanced_Micro_Devices, año 2016...
# Descarga completada para Advanced_Micro_Devices, año 2016.
# Descargando 10-K para Advanced_Micro_Devices, año 2017...
# Descarga completada para Advanced_Micro_Devices, año 2017.
# Descargando 10-K para Advanced_Micro_Devices, año 2018...
# Descarga completada para Advanced_Micro_Devices, año 2018.
# Descargando 10-K para Advanced_Micro_Devices, año 2019...
# Descarga completada para Advanced_Micro_Devices, año 2019.
# Descargando 10-K para Advanced_Micro_Devices, año 2020...
# Descarga completada para Advanced_Micro_Devices, año 2020.
# Descargando 10-K para Advanced_Micro_Devices, año 2021...
# Descarga completada para Advanced_Micro_Devices, año 2021.
# Descargando 10-K para Advanced_Micro_Devices, año 2022...
# Descarga completada para Advanced_Micro_Devices, año 2022.
# Descargando 10-K para Advanced_Micro_Devices, año 2023...
# Descarga completada para Advanced_Micro_Devices, año 2023.
# Descargando 10-K para Advanced_Micro_Devices, año 2024...
# Descarga completada para Advanced_Micro_Devices, año 2024.
# Descargando 10-K para Advanced_Micro_Devices, año 2025...
# Descarga completada para Advanced_Micro_Devices, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-16-000111\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2016-02-18\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-17-000043\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2017-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-18-000042\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2018-02-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-19-000011\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2019-02-08\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-20-000008\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2020-02-04\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-22-000016\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2022-02-03\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-23-000047\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2023-02-27\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-24-000012\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2024-01-31\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0000002488-25-000012\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2025-02-05\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K\0001628280-21-001185\full-submission.txt -> D:\TFM\Analisis_10k\Input\Advanced_Micro_Devices\2021-01-29\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000002488\10-K
# Descargando 10-K para Abbott_Laboratories, año 2016...
# Descarga completada para Abbott_Laboratories, año 2016.
# Descargando 10-K para Abbott_Laboratories, año 2017...
# Descarga completada para Abbott_Laboratories, año 2017.
# Descargando 10-K para Abbott_Laboratories, año 2018...
# Descarga completada para Abbott_Laboratories, año 2018.
# Descargando 10-K para Abbott_Laboratories, año 2019...
# Descarga completada para Abbott_Laboratories, año 2019.
# Descargando 10-K para Abbott_Laboratories, año 2020...
# Descarga completada para Abbott_Laboratories, año 2020.
# Descargando 10-K para Abbott_Laboratories, año 2021...
# Descarga completada para Abbott_Laboratories, año 2021.
# Descargando 10-K para Abbott_Laboratories, año 2022...
# Descarga completada para Abbott_Laboratories, año 2022.
# Descargando 10-K para Abbott_Laboratories, año 2023...
# Descarga completada para Abbott_Laboratories, año 2023.
# Descargando 10-K para Abbott_Laboratories, año 2024...
# Descarga completada para Abbott_Laboratories, año 2024.
# Descargando 10-K para Abbott_Laboratories, año 2025...
# Descarga completada para Abbott_Laboratories, año 2025.
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001047469-16-010246\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2016-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001047469-17-000744\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2017-02-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001047469-18-000856\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2018-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001047469-19-000624\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2019-02-22\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001104659-20-023904\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2020-02-21\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001104659-21-025751\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2021-02-19\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001104659-22-025141\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2022-02-18\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001628280-23-004026\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2023-02-17\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001628280-24-005348\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2024-02-16\full-submission.txt
# Movido D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K\0001628280-25-007110\full-submission.txt -> D:\TFM\Analisis_10k\Input\Abbott_Laboratories\2025-02-21\full-submission.txt
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings\sec-edgar-filings\0000001800\10-K
# Eliminado directorio temporal: D:\TFM\Analisis_10k\temp_10k_filings

# %% [markdown]
# ## Parte 2: Crear archivo con metadatos donde se almacenenen las rutas de los archivos descargados

# %%
## Parte 2: Crear archivo con metadatos donde se almacenenen las rutas de los archivos descargados

# %%
import re
import pandas as pd
from pathlib import Path
from typing import List, Dict
from datetime import datetime
from bs4 import BeautifulSoup

BASE_DIR = "D:/TFM/Analisis_10k"  # o "D:\\10K_Data" si prefieres doble barra

OUTPUT_EXCEL = f"{BASE_DIR}/10k_filings_metadata.xlsx"
COMPANIES_EXCEL = f"{BASE_DIR}/companies_cik.xlsx"



def load_companies_from_excel(excel_path: Path) -> List[Dict]:
    try:
        df = pd.read_excel(excel_path)
        companies = df.to_dict('records')

        required_columns = ['company_name', 'cik', 'input_dir', 'output_dir']
        if not all(col in df.columns for col in required_columns):
            missing = [col for col in required_columns if col not in df.columns]
            raise ValueError(f"Faltan columnas en el Excel: {missing}")
        
        return companies
    except Exception as e:
        print(f"Error al leer el archivo Excel {excel_path}: {e}")
        return []

def extract_10k_text(text: str) -> str:
    documents = re.findall(r'<DOCUMENT>(.*?)</DOCUMENT>', text, re.DOTALL)
    for doc in documents:
        type_match = re.search(r'<TYPE>(.+)', doc)
        if type_match and type_match.group(1).strip().upper() == '10-K':
            text_match = re.search(r'<TEXT>(.*?)</TEXT>', doc, re.DOTALL)
            if text_match:
                return text_match.group(1)

    soup = BeautifulSoup(text, 'html.parser')
    documents = soup.find_all('document')
    for doc in documents:
        doc_type = doc.find('type')
        if doc_type and doc_type.text.strip().upper() == '10-K':
            text_tag = doc.find('text')
            if text_tag:
                return text_tag.text
    return None

def extract_filing_date(original_text: str) -> datetime:
    match = re.search(r'<FILING-DATE>(\d{8})', original_text)
    if match:
        return pd.to_datetime(match.group(1), format='%Y%m%d')
    match = re.search(r'<ACCEPTANCE-DATETIME>(\d{8})', original_text)
    if match:
        return pd.to_datetime(match.group(1), format='%Y%m%d')

    soup = BeautifulSoup(original_text, 'html.parser')
    for tag in soup.find_all(text=re.compile(r'(FILING-DATE|ACCEPTANCE-DATETIME)')):
        match = re.search(r'\d{8}', tag)
        if match:
            return pd.to_datetime(match.group(0), format='%Y%m%d')
    return None

def clean_and_save_filings(
    input_dir: str,
    output_dir: str,
    company_name: str,
    cik: str
) -> List[Dict]:
    
    filings = []
    input_path = Path(input_dir)
    output_base = Path(output_dir)

    for file_path in input_path.rglob("*.txt"):
        filing_date_str = file_path.parent.name
        try:
            filing_date = datetime.strptime(filing_date_str, "%Y-%m-%d")
        except ValueError:
            print(f"Omitiendo {file_path}: Nombre de carpeta no es una fecha válida")
            continue

        try:
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                original_text = f.read()

            clean_text = extract_10k_text(original_text)
            if not clean_text:
                print(f"Omitiendo {file_path}: No se extrajo texto 10-K válido")
                continue

            output_dir = output_base / filing_date_str
            output_dir.mkdir(parents=True, exist_ok=True)

            filing_year = filing_date.year
            output_filename = f"{company_name.replace(' ', '_')}_{filing_year}_clean.txt"
            output_file_path = output_dir / output_filename

            with open(output_file_path, 'w', encoding='utf-8') as f_out:
                f_out.write(clean_text)

            filings.append({
                "date": filing_date,
                "year": filing_year,
                "company": company_name,
                "CIK": cik,
                "file_path": str(output_file_path)
            })
            print(f"Procesado {file_path} -> {output_file_path}")

        except Exception as e:
            print(f"Error procesando {file_path}: {e}")

    return filings


def main():
    companies = load_companies_from_excel(COMPANIES_EXCEL)
    if not companies:
        print("No se cargaron empresas. Terminando ejecución.")
        return

    all_cleaned_filings = []
    for company in companies:
        # Convertimos rutas relativas a absolutas con respecto a BASE_DIR
        input_dir = str(Path(BASE_DIR) / company["input_dir"].lstrip("/\\"))
        output_dir = str(Path(BASE_DIR) / company["output_dir"].lstrip("/\\"))

        cleaned = clean_and_save_filings(
            input_dir=input_dir,
            output_dir=output_dir,
            company_name=company["company_name"],
            cik=company["cik"]
full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Abbott_Laboratories\2025-02-21\Abbott_Laboratories_2025_clean.txt
# Metadatos guardados en D:/TFM/Analisis_10k/10k_filings_metadata.xlsx

# %%
df_10k_clean.shape
# Out:
# (4717, 5)

# %%
import re
import pandas as pd
from pathlib import Path
from typing import List, Dict
from datetime import datetime
from bs4 import BeautifulSoup

BASE_DIR = "D:/TFM/Analisis_10k"

OUTPUT_EXCEL = f"{BASE_DIR}/10k_filings_metadata2.xlsx"
COMPANIES_EXCEL = f"{BASE_DIR}/companies_cik.xlsx"

def load_companies_from_excel(excel_path: Path) -> List[Dict]:
    try:
        df = pd.read_excel(excel_path)
        companies = df.to_dict('records')

        required_columns = ['company_name', 'cik', 'input_dir', 'output_dir']
        if not all(col in df.columns for col in required_columns):
            missing = [col for col in required_columns if col not in df.columns]
            raise ValueError(f"Faltan columnas en el Excel: {missing}")
        
        return companies
    except Exception as e:
        print(f"Error al leer el archivo Excel {excel_path}: {e}")
        return []

def extract_10k_text(text: str) -> str:
    documents = re.findall(r'<DOCUMENT>(.*?)</DOCUMENT>', text, re.DOTALL)
    for doc in documents:
        type_match = re.search(r'<TYPE>(.+)', doc)
        if type_match and type_match.group(1).strip().upper() == '10-K':
            text_match = re.search(r'<TEXT>(.*?)</TEXT>', doc, re.DOTALL)
            if text_match:
                return text_match.group(1)

    soup = BeautifulSoup(text, 'html.parser')
    documents = soup.find_all('document')
    for doc in documents:
        doc_type = doc.find('type')
        if doc_type and doc_type.text.strip().upper() == '10-K':
            text_tag = doc.find('text')
            if text_tag:
                return text_tag.text
    return None

def clean_html_with_bs(text: str) -> str:
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text(separator=' ', strip=True)

def extract_relevant_text(text: str, phrase: str = "financial condition") -> str:
    if not text or not phrase:
        return text
    index = text.lower().find(phrase.lower())
    return text[index:].strip() if index != -1 else text.strip()

#def extract_item_7_to_7a(text: str) -> str:
#    pattern = r'(?s)(ITEM\s*7\.)(.*?)(?=ITEM\s*7a\.)'
#    match = re.search(pattern, text, re.IGNORECASE)
#    return match.group(0) if match else None

def extract_item_7_to_7a(text: str) -> str:
    pattern = r'(?s)((?:I\s*T\s*E\s*M|ITEM)\s*7\.)(.*?)(?=(?:I\s*T\s*E\s*M|ITEM)\s*7a\.)'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(0)
    return match.group(0) if match else None

def extract_filing_date(original_text: str) -> datetime:
    match = re.search(r'<FILING-DATE>(\d{8})', original_text)
    if match:
        return pd.to_datetime(match.group(1), format='%Y%m%d')
    match = re.search(r'<ACCEPTANCE-DATETIME>(\d{8})', original_text)
    if match:
        return pd.to_datetime(match.group(1), format='%Y%m%d')

    soup = BeautifulSoup(original_text, 'html.parser')
    for tag in soup.find_all(text=re.compile(r'(FILING-DATE|ACCEPTANCE-DATETIME)')):
        match = re.search(r'\d{8}', tag)
        if match:
            return pd.to_datetime(match.group(0), format='%Y%m%d')
    return None

def clean_and_save_filings(input_dir: str, output_dir: str, company_name: str, cik: str) -> List[Dict]:
    filings = []
    input_path = Path(input_dir)
    output_base = Path(output_dir)

    for file_path in input_path.rglob("*.txt"):
        filing_date_str = file_path.parent.name
        try:
            filing_date = datetime.strptime(filing_date_str, "%Y-%m-%d")
        except ValueError:
            print(f"Omitiendo {file_path}: Nombre de carpeta no es una fecha válida")
            continue

        try:
            with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                original_text = f.read()

            raw_text = extract_10k_text(original_text)
            if not raw_text:
                print(f"Omitiendo {file_path}: No se extrajo texto 10-K válido")
                continue

            text_cleaned = clean_html_with_bs(raw_text)
            relevant_text = extract_relevant_text(text_cleaned)
            item_7_text = extract_item_7_to_7a(relevant_text)

            if not item_7_text:
                print(f"Omitiendo {file_path}: No se extrajo sección ITEM 7 a 7A")
                continue

            output_dir = output_base / filing_date_str
            output_dir.mkdir(parents=True, exist_ok=True)

            filing_year = filing_date.year
            output_filename = f"{company_name.replace(' ', '_')}_{filing_year}_item7.txt"
            output_file_path = output_dir / output_filename

            with open(output_file_path, 'w', encoding='utf-8') as f_out:
                f_out.write(item_7_text)

            filings.append({
                "date": filing_date,
                "year": filing_year,
                "company": company_name,
                "CIK": cik,
                "file_path": str(output_file_path)
            })
            print(f"Procesado {file_path} -> {output_file_path}")

        except Exception as e:
            print(f"Error procesando {file_path}: {e}")

    return filings

def main():
    companies = load_companies_from_excel(COMPANIES_EXCEL)
    if not companies:
        print("No se cargaron empresas. Terminando ejecución.")
        return

    all_cleaned_filings = []
    for company in companies:
        input_dir = str(Path(BASE_DIR) / company["input_dir"].lstrip("/\\"))
        output_dir = str(Path(BASE_DIR) / company["output_dir"].lstrip("/\\"))

        cleaned = clean_and_save_filings(
            input_dir=input_dir,
            output_dir=output_dir,
            company_name=company["company_name"],
            cik=company["cik"]
        )
        all_cleaned_filings.extend(cleaned)

    if all_cleaned_filings:
        df_10k_clean = pd.DataFrame(all_cleaned_filings)
        try:
            df_10k_clean.to_excel(OUTPUT_EXCEL, index=False)
            print(f"Metadatos guardados en {OUTPUT_EXCEL}")
        except Exception as e:
            print(f"Error guardando metadatos en {OUTPUT_EXCEL}: {e}")
        return df_10k_clean
    else:
        print("No se procesaron formularios. No se creó el archivo Excel.")
        return None

if __name__ == "__main__":
    df_10k_clean = main()
# Out:
# Procesado D:\TFM\Analisis_10k\Input\BlackRock\2025-02-25\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\BlackRock\2025-02-25\BlackRock_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Smurfit_Westrock\2025-03-07\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Smurfit_Westrock\2025-03-07\Smurfit_Westrock_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Bunge_Global\2024-02-22\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Bunge_Global\2024-02-22\Bunge_Global_2024_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Bunge_Global\2025-02-20\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Bunge_Global\2025-02-20\Bunge_Global_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\GE_Vernova\2025-02-06\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\GE_Vernova\2025-02-06\GE_Vernova_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\TKO_Group_Holdings\2024-02-27\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\TKO_Group_Holdings\2024-02-27\TKO_Group_Holdings_2024_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\TKO_Group_Holdings\2025-02-26\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\TKO_Group_Holdings\2025-02-26\TKO_Group_Holdings_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Veralto\2024-02-28\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Veralto\2024-02-28\Veralto_2024_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Veralto\2025-02-25\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Veralto\2025-02-25\Veralto_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Solventum\2025-02-28\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Solventum\2025-02-28\Solventum_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Kenvue\2024-03-01\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Kenvue\2024-03-01\Kenvue_2024_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\Kenvue\2025-02-24\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean\Kenvue\2025-02-24\Kenvue_2025_item7.txt
# Procesado D:\TFM\Analisis_10k\Input\GE_HealthCare\2023-02-15\full-submission.txt -> D:\TFM\Analisis_10k\Input_clean